# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from glob import iglob
from math import log, floor
import os
import re
import pickle

# %reload_ext autoreload
# %autoreload 2

from lib.plot_utils import *
from lib.cdf_utils import *
from lib.scatter_utils import *

# %% [markdown]
# ## Scatter Plot of Maximum Concurrent Flow

# %%
def pop_random_scatter(path_form_csv, pop_csv, query_str, title):
    with_kdl = "problem == 'Kdl.graphml'"
    no_kdl = "problem != 'Kdl.graphml'"
    ratio_dfs = get_ratio_dataframes(path_form_csv, pop_csv,
        pop_parent_query_str=query_str,
        pop_query_strs=[with_kdl, no_kdl]
    )
    plot_dfs = [ratio_dfs["POP"][with_kdl], ratio_dfs["POP"][no_kdl]]
    scatter_plot(plot_dfs,
            ["KDL", "Non-KDL"],
            ["nc", "smore", "pf"],
            "speedup_ratio",
            "obj_val_ratio",
            xlim=None,
            ylim=[0.0, 1.1],
            figsize=(7.5, 4),
            xlabel='Speedup ratio (to original)',
            ylabel='Min. fractional flow\nratio (to original)',
            bbta=(0, 0, 1, 2.35),
            ncol=2,
            xlog=True,
            save=True)

# %%
path_form_csv = 'max_concurrent_flow_csvs/path-form-mcf-slice_0.csv'
pop_csv = 'max_concurrent_flow_csvs/pop-mcf-slice_0.csv'

# %%
pop_random_scatter(path_form_csv, pop_csv, "split_method == 'random' and num_subproblems == 16 and (tm_model == 'poisson-high-intra' and split_fraction == 0.75) or (tm_model != 'poisson-high-intra' and split_fraction == 0.0)", "Poisson, High Intra")

# %%
pop_random_scatter(path_form_csv, pop_csv,
                   "tm_model == 'poisson-high-inter'", "Poisson, High Inter")
# Out:
#         problem            tm_model  traffic_seed  scale_factor  flow_ratio  \
# 0   Kdl.graphml             gravity    1947258216           1.0    1.000000
# 1   Kdl.graphml             gravity    1640115421           2.0    1.000000
# 2   Kdl.graphml             gravity     102333321           4.0    1.000000
# 3   Kdl.graphml             gravity    1876254433           8.0    1.000000
# 4   Kdl.graphml             gravity    1710674203          16.0    0.976811
# 5   Kdl.graphml             gravity     133885275          32.0    0.965524
# 6   Kdl.graphml             gravity    1022240448          64.0    0.982774
# 7   Kdl.graphml             gravity    1034240991         128.0    0.973235
# 8   Kdl.graphml  poisson-high-intra    1158533055           1.0    1.000000
# 9   Kdl.graphml  poisson-high-intra    1771706265          64.0    0.876343
# 10  Kdl.graphml  poisson-high-intra    1303852474         128.0    0.853139
#
#     speedup_ratio
# 0       23.278258
# 1       30.353398
# 2       71.238395
# 3      443.817221
# 4      422.236543
# 5      723.939728
# 6      288.735578
# 7      152.679486
# 8       27.662511
# 9       17.215959
# 10      50.481725
#                problem            tm_model  traffic_seed  scale_factor  \
# 0     Cogentco.graphml             gravity    1374632450           1.0
# 1     Cogentco.graphml             gravity    1176656848           2.0
# 2     Cogentco.graphml             gravity    1425924102           4.0
# 3     Cogentco.graphml             gravity    1877587945           8.0
# 4     Cogentco.graphml             gravity    1085483962          16.0
# ..                 ...                 ...           ...           ...
# 107  UsCarrier.graphml  poisson-high-intra    1196923204           8.0
# 108  UsCarrier.graphml  poisson-high-intra    1281112752          16.0
# 109  UsCarrier.graphml  poisson-high-intra    1149123775          32.0
# 110  UsCarrier.graphml  poisson-high-intra    1022383118          64.0
# 111  UsCarrier.graphml  poisson-high-intra    1034066240         128.0
#
#      flow_ratio  speedup_ratio
# 0      1.000000      15.893150
# 1      1.000000      24.007579
# 2      1.000000      28.918729
# 3      1.000000      68.464158
# 4      0.913368      73.677220
# ..          ...            ...
# 107    0.617597       6.824530
# 108    0.537666      19.942650
# 109    0.505613      17.861873
# 110    0.517983      20.412033
# 111    0.561382      21.460329
#
# [112 rows x 6 columns]
# KDL Empty DataFrame
# Columns: [problem, tm_model, traffic_seed, scale_factor, flow_ratio, speedup_ratio]
# Index: []
# Non-KDL Empty DataFrame
# Columns: [problem, tm_model, traffic_seed, scale_factor, flow_ratio, speedup_ratio]
# Index: []

# %%
pop_random_scatter(path_form_csv, pop_csv,
                   "tm_model == 'uniform'", "Uniform")
# Out:
#         problem            tm_model  traffic_seed  scale_factor  flow_ratio  \
# 0   Kdl.graphml             gravity    1947258216           1.0    1.000000
# 1   Kdl.graphml             gravity    1640115421           2.0    1.000000
# 2   Kdl.graphml             gravity     102333321           4.0    1.000000
# 3   Kdl.graphml             gravity    1876254433           8.0    1.000000
# 4   Kdl.graphml             gravity    1710674203          16.0    0.976811
# 5   Kdl.graphml             gravity     133885275          32.0    0.965524
# 6   Kdl.graphml             gravity    1022240448          64.0    0.982774
# 7   Kdl.graphml             gravity    1034240991         128.0    0.973235
# 8   Kdl.graphml  poisson-high-intra    1158533055           1.0    1.000000
# 9   Kdl.graphml  poisson-high-intra    1771706265          64.0    0.876343
# 10  Kdl.graphml  poisson-high-intra    1303852474         128.0    0.853139
#
#     speedup_ratio
# 0       23.278258
# 1       30.353398
# 2       71.238395
# 3      443.817221
# 4      422.236543
# 5      723.939728
# 6      288.735578
# 7      152.679486
# 8       27.662511
# 9       17.215959
# 10      50.481725
#                problem            tm_model  traffic_seed  scale_factor  \
# 0     Cogentco.graphml             gravity    1374632450           1.0
# 1     Cogentco.graphml             gravity    1176656848           2.0
# 2     Cogentco.graphml             gravity    1425924102           4.0
# 3     Cogentco.graphml             gravity    1877587945           8.0
# 4     Cogentco.graphml             gravity    1085483962          16.0
# ..                 ...                 ...           ...           ...
# 107  UsCarrier.graphml  poisson-high-intra    1196923204           8.0
# 108  UsCarrier.graphml  poisson-high-intra    1281112752          16.0
# 109  UsCarrier.graphml  poisson-high-intra    1149123775          32.0
# 110  UsCarrier.graphml  poisson-high-intra    1022383118          64.0
# 111  UsCarrier.graphml  poisson-high-intra    1034066240         128.0
#
#      flow_ratio  speedup_ratio
# 0      1.000000      15.893150
# 1      1.000000      24.007579
# 2      1.000000      28.918729
# 3      1.000000      68.464158
# 4      0.913368      73.677220
# ..          ...            ...
# 107    0.617597       6.824530
# 108    0.537666      19.942650
# 109    0.505613      17.861873
# 110    0.517983      20.412033
# 111    0.561382      21.460329
#
# [112 rows x 6 columns]
# KDL Empty DataFrame
# Columns: [problem, tm_model, traffic_seed, scale_factor, flow_ratio, speedup_ratio]
# Index: []
# Non-KDL Empty DataFrame
# Columns: [problem, tm_model, traffic_seed, scale_factor, flow_ratio, speedup_ratio]
# Index: []

# %%
pop_random_scatter(path_form_csv, pop_csv,
                   "tm_model == 'gravity'", "Gravity")
# Out:
#         problem            tm_model  traffic_seed  scale_factor  flow_ratio  \
# 0   Kdl.graphml             gravity    1947258216           1.0    1.000000
# 1   Kdl.graphml             gravity    1640115421           2.0    1.000000
# 2   Kdl.graphml             gravity     102333321           4.0    1.000000
# 3   Kdl.graphml             gravity    1876254433           8.0    1.000000
# 4   Kdl.graphml             gravity    1710674203          16.0    0.976811
# 5   Kdl.graphml             gravity     133885275          32.0    0.965524
# 6   Kdl.graphml             gravity    1022240448          64.0    0.982774
# 7   Kdl.graphml             gravity    1034240991         128.0    0.973235
# 8   Kdl.graphml  poisson-high-intra    1158533055           1.0    1.000000
# 9   Kdl.graphml  poisson-high-intra    1771706265          64.0    0.876343
# 10  Kdl.graphml  poisson-high-intra    1303852474         128.0    0.853139
#
#     speedup_ratio
# 0       23.278258
# 1       30.353398
# 2       71.238395
# 3      443.817221
# 4      422.236543
# 5      723.939728
# 6      288.735578
# 7      152.679486
# 8       27.662511
# 9       17.215959
# 10      50.481725
#                problem            tm_model  traffic_seed  scale_factor  \
# 0     Cogentco.graphml             gravity    1374632450           1.0
# 1     Cogentco.graphml             gravity    1176656848           2.0
# 2     Cogentco.graphml             gravity    1425924102           4.0
# 3     Cogentco.graphml             gravity    1877587945           8.0
# 4     Cogentco.graphml             gravity    1085483962          16.0
# ..                 ...                 ...           ...           ...
# 107  UsCarrier.graphml  poisson-high-intra    1196923204           8.0
# 108  UsCarrier.graphml  poisson-high-intra    1281112752          16.0
# 109  UsCarrier.graphml  poisson-high-intra    1149123775          32.0
# 110  UsCarrier.graphml  poisson-high-intra    1022383118          64.0
# 111  UsCarrier.graphml  poisson-high-intra    1034066240         128.0
#
#      flow_ratio  speedup_ratio
# 0      1.000000      15.893150
# 1      1.000000      24.007579
# 2      1.000000      28.918729
# 3      1.000000      68.464158
# 4      0.913368      73.677220
# ..          ...            ...
# 107    0.617597       6.824530
# 108    0.537666      19.942650
# 109    0.505613      17.861873
# 110    0.517983      20.412033
# 111    0.561382      21.460329
#
# [112 rows x 6 columns]
# KDL        problem tm_model  traffic_seed  scale_factor  flow_ratio  speedup_ratio
# 0  Kdl.graphml  gravity    1947258216           1.0    1.000000      23.278258
# 1  Kdl.graphml  gravity    1640115421           2.0    1.000000      30.353398
# 2  Kdl.graphml  gravity     102333321           4.0    1.000000      71.238395
# 3  Kdl.graphml  gravity    1876254433           8.0    1.000000     443.817221
# 4  Kdl.graphml  gravity    1710674203          16.0    0.976811     422.236543
# 5  Kdl.graphml  gravity     133885275          32.0    0.965524     723.939728
# 6  Kdl.graphml  gravity    1022240448          64.0    0.982774     288.735578
# 7  Kdl.graphml  gravity    1034240991         128.0    0.973235     152.679486
# Non-KDL                    problem tm_model  traffic_seed  scale_factor  flow_ratio  \
# 0         Cogentco.graphml  gravity    1374632450           1.0    1.000000
# 1         Cogentco.graphml  gravity    1176656848           2.0    1.000000
# 2         Cogentco.graphml  gravity    1425924102           4.0    1.000000
# 3         Cogentco.graphml  gravity    1877587945           8.0    1.000000
# 4         Cogentco.graphml  gravity    1085483962          16.0    0.913368
# 5         Cogentco.graphml  gravity    1486627102          32.0    0.904057
# 6         Cogentco.graphml  gravity    1229219359          64.0    0.875131
# 7         Cogentco.graphml  gravity     142626253         128.0    0.918633
# 16            Colt.graphml  gravity    1041669110           1.0    1.000000
# 17            Colt.graphml  gravity    1117579738           2.0    1.000000
# 18            Colt.graphml  gravity    1111060477           4.0    1.000000
# 19            Colt.graphml  gravity     121297824           8.0    1.000000
# 20            Colt.graphml  gravity    1108214735          16.0    0.793873
# 21            Colt.graphml  gravity    1002058247          32.0    0.859316
# 22            Colt.graphml  gravity    1200865651          64.0    0.804825
# 23            Colt.graphml  gravity    1141211829         128.0    0.857146
# 32        Deltacom.graphml  gravity    1268341991           1.0    1.000000
# 33        Deltacom.graphml  gravity     128300277           2.0    1.000000
# 34        Deltacom.graphml  gravity    1668474457           4.0    1.000000
# 35        Deltacom.graphml  gravity      13036757           8.0    1.000000
# 36        Deltacom.graphml  gravity     119644466          16.0    0.839459
# 37        Deltacom.graphml  gravity     168131741          32.0    0.794014
# 38        Deltacom.graphml  gravity    1307039078          64.0    0.829089
# 39        Deltacom.graphml  gravity      12790396         128.0    0.872489
# 48   DialtelecomCz.graphml  gravity    1536565063           1.0    1.000000
# 49   DialtelecomCz.graphml  gravity    1374272211           2.0    1.000000
# 50   DialtelecomCz.graphml  gravity    2043794026           4.0    1.000000
# 51   DialtelecomCz.graphml  gravity    1177303366           8.0    0.961018
# 52   DialtelecomCz.graphml  gravity    1064113957          16.0    0.897569
# 53   DialtelecomCz.graphml  gravity    1200931432          32.0    0.886591
# 54   DialtelecomCz.graphml  gravity    1185012436          64.0    0.864965
# 55   DialtelecomCz.graphml  gravity    1288319454         128.0    0.876170
# 64           GtsCe.graphml  gravity    1479688182           1.0    1.000000
# 65           GtsCe.graphml  gravity    1283401444           2.0    1.000000
# 66           GtsCe.graphml  gravity    1088539607           4.0    1.000000
# 67           GtsCe.graphml  gravity    1956926541           8.0    1.000000
# 68           GtsCe.graphml  gravity    1033617822          16.0    1.000000
# 69           GtsCe.graphml  gravity    1192263082          32.0    0.841017
# 70           GtsCe.graphml  gravity    1321948195          64.0    0.837457
# 71           GtsCe.graphml  gravity      12734199         128.0    0.884608
# 80         TataNld.graphml  gravity    1148601493           1.0    1.000000
# 81         TataNld.graphml  gravity    1257688362           2.0    1.000000
# 82         TataNld.graphml  gravity      11412112           4.0    1.000000
# 83         TataNld.graphml  gravity    1555020805           8.0    1.000000
# 84         TataNld.graphml  gravity    1628983645          16.0    0.827609
# 85         TataNld.graphml  gravity    1004732208          32.0    0.845176
# 86         TataNld.graphml  gravity    1180050477          64.0    0.859692
# 87         TataNld.graphml  gravity    1093445293         128.0    0.882966
# 96       UsCarrier.graphml  gravity     126410113           1.0    1.000000
# 97       UsCarrier.graphml  gravity     123874486           2.0    1.000000
# 98       UsCarrier.graphml  gravity      63124174           4.0    1.000000
# 99       UsCarrier.graphml  gravity    2021178515           8.0    1.000000
# 100      UsCarrier.graphml  gravity     146569124          16.0    0.907324
# 101      UsCarrier.graphml  gravity    1416924748          32.0    0.904030
# 102      UsCarrier.graphml  gravity    1604631843          64.0    0.853150
# 103      UsCarrier.graphml  gravity    1454580274         128.0    0.915346
#
#      speedup_ratio
# 0        15.893150
# 1        24.007579
# 2        28.918729
# 3        68.464158
# 4        73.677220
# 5        69.330176
# 6        56.313566
# 7        49.835696
# 16       12.742689
# 17       13.625075
# 18       13.208133
# 19       86.648475
# 20       52.042501
# 21       47.582675
# 22       68.041873
# 23       62.273195
# 32        7.932486
# 33       17.011493
# 34       13.985029
# 35       20.685437
# 36       34.351500
# 37       29.898241
# 38       33.361520
# 39       26.272467
# 48       14.107172
# 49       20.562866
# 50       31.442956
# 51       36.414685
# 52       41.442681
# 53       38.916462
# 54       38.188292
# 55       45.938902
# 64       10.022184
# 65        8.691556
# 66       13.290692
# 67       11.885607
# 68       39.396756
# 69       38.001643
# 70       34.589757
# 71       46.720553
# 80       13.478566
# 81       11.047803
# 82       14.985863
# 83       34.282501
# 84       45.848976
# 85       38.671373
# 86       28.484026
# 87       28.300824
# 96       12.758073
# 97       17.408161
# 98       18.089351
# 99       52.106422
# 100      68.003966
# 101      63.305444
# 102      44.941640
# 103      53.214331

# %%
pop_random_scatter(path_form_csv, pop_csv,
                   "tm_model == 'bimodal'", "Bimodal")
# Out:
#         problem            tm_model  traffic_seed  scale_factor  flow_ratio  \
# 0   Kdl.graphml             gravity    1947258216           1.0    1.000000
# 1   Kdl.graphml             gravity    1640115421           2.0    1.000000
# 2   Kdl.graphml             gravity     102333321           4.0    1.000000
# 3   Kdl.graphml             gravity    1876254433           8.0    1.000000
# 4   Kdl.graphml             gravity    1710674203          16.0    0.976811
# 5   Kdl.graphml             gravity     133885275          32.0    0.965524
# 6   Kdl.graphml             gravity    1022240448          64.0    0.982774
# 7   Kdl.graphml             gravity    1034240991         128.0    0.973235
# 8   Kdl.graphml  poisson-high-intra    1158533055           1.0    1.000000
# 9   Kdl.graphml  poisson-high-intra    1771706265          64.0    0.876343
# 10  Kdl.graphml  poisson-high-intra    1303852474         128.0    0.853139
#
#     speedup_ratio
# 0       23.278258
# 1       30.353398
# 2       71.238395
# 3      443.817221
# 4      422.236543
# 5      723.939728
# 6      288.735578
# 7      152.679486
# 8       27.662511
# 9       17.215959
# 10      50.481725
#                problem            tm_model  traffic_seed  scale_factor  \
# 0     Cogentco.graphml             gravity    1374632450           1.0
# 1     Cogentco.graphml             gravity    1176656848           2.0
# 2     Cogentco.graphml             gravity    1425924102           4.0
# 3     Cogentco.graphml             gravity    1877587945           8.0
# 4     Cogentco.graphml             gravity    1085483962          16.0
# ..                 ...                 ...           ...           ...
# 107  UsCarrier.graphml  poisson-high-intra    1196923204           8.0
# 108  UsCarrier.graphml  poisson-high-intra    1281112752          16.0
# 109  UsCarrier.graphml  poisson-high-intra    1149123775          32.0
# 110  UsCarrier.graphml  poisson-high-intra    1022383118          64.0
# 111  UsCarrier.graphml  poisson-high-intra    1034066240         128.0
#
#      flow_ratio  speedup_ratio
# 0      1.000000      15.893150
# 1      1.000000      24.007579
# 2      1.000000      28.918729
# 3      1.000000      68.464158
# 4      0.913368      73.677220
# ..          ...            ...
# 107    0.617597       6.824530
# 108    0.537666      19.942650
# 109    0.505613      17.861873
# 110    0.517983      20.412033
# 111    0.561382      21.460329
#
# [112 rows x 6 columns]
# KDL Empty DataFrame
# Columns: [problem, tm_model, traffic_seed, scale_factor, flow_ratio, speedup_ratio]
# Index: []
# Non-KDL Empty DataFrame
# Columns: [problem, tm_model, traffic_seed, scale_factor, flow_ratio, speedup_ratio]
# Index: []

# %%
pop_random_scatter(path_form_csv, pop_csv,
                   None, "all")
# Out:
#         problem            tm_model  traffic_seed  scale_factor  flow_ratio  \
# 0   Kdl.graphml             gravity    1947258216           1.0    1.000000
# 1   Kdl.graphml             gravity    1640115421           2.0    1.000000
# 2   Kdl.graphml             gravity     102333321           4.0    1.000000
# 3   Kdl.graphml             gravity    1876254433           8.0    1.000000
# 4   Kdl.graphml             gravity    1710674203          16.0    0.976811
# 5   Kdl.graphml             gravity     133885275          32.0    0.965524
# 6   Kdl.graphml             gravity    1022240448          64.0    0.982774
# 7   Kdl.graphml             gravity    1034240991         128.0    0.973235
# 8   Kdl.graphml  poisson-high-intra    1158533055           1.0    1.000000
# 9   Kdl.graphml  poisson-high-intra    1771706265          64.0    0.876343
# 10  Kdl.graphml  poisson-high-intra    1303852474         128.0    0.853139
#
#     speedup_ratio
# 0       23.278258
# 1       30.353398
# 2       71.238395
# 3      443.817221
# 4      422.236543
# 5      723.939728
# 6      288.735578
# 7      152.679486
# 8       27.662511
# 9       17.215959
# 10      50.481725
#                problem            tm_model  traffic_seed  scale_factor  \
# 0     Cogentco.graphml             gravity    1374632450           1.0
# 1     Cogentco.graphml             gravity    1176656848           2.0
# 2     Cogentco.graphml             gravity    1425924102           4.0
# 3     Cogentco.graphml             gravity    1877587945           8.0
# 4     Cogentco.graphml             gravity    1085483962          16.0
# ..                 ...                 ...           ...           ...
# 107  UsCarrier.graphml  poisson-high-intra    1196923204           8.0
# 108  UsCarrier.graphml  poisson-high-intra    1281112752          16.0
# 109  UsCarrier.graphml  poisson-high-intra    1149123775          32.0
# 110  UsCarrier.graphml  poisson-high-intra    1022383118          64.0
# 111  UsCarrier.graphml  poisson-high-intra    1034066240         128.0
#
#      flow_ratio  speedup_ratio
# 0      1.000000      15.893150
# 1      1.000000      24.007579
# 2      1.000000      28.918729
# 3      1.000000      68.464158
# 4      0.913368      73.677220
# ..          ...            ...
# 107    0.617597       6.824530
# 108    0.537666      19.942650
# 109    0.505613      17.861873
# 110    0.517983      20.412033
# 111    0.561382      21.460329
#
# [112 rows x 6 columns]
# KDL         problem            tm_model  traffic_seed  scale_factor  flow_ratio  \
# 0   Kdl.graphml             gravity    1947258216           1.0    1.000000
# 1   Kdl.graphml             gravity    1640115421           2.0    1.000000
# 2   Kdl.graphml             gravity     102333321           4.0    1.000000
# 3   Kdl.graphml             gravity    1876254433           8.0    1.000000
# 4   Kdl.graphml             gravity    1710674203          16.0    0.976811
# 5   Kdl.graphml             gravity     133885275          32.0    0.965524
# 6   Kdl.graphml             gravity    1022240448          64.0    0.982774
# 7   Kdl.graphml             gravity    1034240991         128.0    0.973235
# 8   Kdl.graphml  poisson-high-intra    1158533055           1.0    1.000000
# 9   Kdl.graphml  poisson-high-intra    1771706265          64.0    0.876343
# 10  Kdl.graphml  poisson-high-intra    1303852474         128.0    0.853139
#
#     speedup_ratio
# 0       23.278258
# 1       30.353398
# 2       71.238395
# 3      443.817221
# 4      422.236543
# 5      723.939728
# 6      288.735578
# 7      152.679486
# 8       27.662511
# 9       17.215959
# 10      50.481725
# Non-KDL                problem            tm_model  traffic_seed  scale_factor  \
# 0     Cogentco.graphml             gravity    1374632450           1.0
# 1     Cogentco.graphml             gravity    1176656848           2.0
# 2     Cogentco.graphml             gravity    1425924102           4.0
# 3     Cogentco.graphml             gravity    1877587945           8.0
# 4     Cogentco.graphml             gravity    1085483962          16.0
# ..                 ...                 ...           ...           ...
# 107  UsCarrier.graphml  poisson-high-intra    1196923204           8.0
# 108  UsCarrier.graphml  poisson-high-intra    1281112752          16.0
# 109  UsCarrier.graphml  poisson-high-intra    1149123775          32.0
# 110  UsCarrier.graphml  poisson-high-intra    1022383118          64.0
# 111  UsCarrier.graphml  poisson-high-intra    1034066240         128.0
#
#      flow_ratio  speedup_ratio
# 0      1.000000      15.893150
# 1      1.000000      24.007579
# 2      1.000000      28.918729
# 3      1.000000      68.464158
# 4      0.913368      73.677220
# ..          ...            ...
# 107    0.617597       6.824530
# 108    0.537666      19.942650
# 109    0.505613      17.861873
# 110    0.517983      20.412033
# 111    0.561382      21.460329
#
# [112 rows x 6 columns]
